# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import requests
import time
from datetime import datetime
from config import weather_api_key

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high= 90.000, size=2000) 
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
#Test and Troubleshooting
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Boston"
#city_weather = requests.get(city_url)
#city_weather
# Get the JSON text of the 'Get' request.
#city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 25.27,
#   'feels_like': 15.85,
#   'temp_min': 22.28,
#   'temp_max': 27.99,
#   'pressure': 1025,
#   'humidity': 52},
#  'visibility': 10000,
#  'wind': {'speed': 9.22, 'deg': 360},
#  'clouds': {'all': 20},
#  'dt': 1675217269,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1675166348,
#   'sunset': 1675202162},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count +=1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
            # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
                 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]

        city_date=datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M%S")    
            # Append the city information into the city_data list
           
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity":city_humidity,
                            "Cloudiness":city_clouds,
                            "Wind Speed": city_wind_speed,
                            "Current Weather":city_weather_description,
                            "Country":city_country})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | awjilah
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | kavieng
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | sitka
# Processing Record 9 of Set 1 | dolores
# Processing Record 10 of Set 1 | walla walla
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | malanje
# Processing Record 14 of Set 1 | traverse city
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | pangnirtung
# Processing Record 17 of Set 1 | kysyl-syr
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | lavrentiya
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | lompoc
# Processing Record 24 of Set 1 | road town
# Processing Record 25 of Set 1 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 1 | mildura
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 1 | moerai
# Processing Record 36 of Set 1 | barra patuca
# Processing Record 37 of Set 1 | issia
# Processing Record 38 of Set 1 | visby
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | pinillos
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | jennings
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | airai
# Processing Record 46 of Set 1 | pakxan
# Processing Record 47 of Set 1 | southbridge
# Processing Record 48 of Set 1 | pisco
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | vlasenica
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | karratha
# Processing Record 4 of Set 2 | gunnedah
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | saint george
# Processing Record 7 of Set 2 | pacific grove
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | tual
# Processing Record 10 of Set 2 | auki
# Processing Record 11 of Set 2 | puerto ayora
# Processing Record 12 of Set 2 | diu
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | camacari
# Processing Record 16 of Set 2 | teluk nibung
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | cap malheureux
# Processing Record 19 of Set 2 | batemans bay
# Processing Record 20 of Set 2 | mandiana
# Processing Record 21 of Set 2 | galliate
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | siocon
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | mwinilunga
# Processing Record 27 of Set 2 | manta
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | avera
# Processing Record 30 of Set 2 | villamontes
# Processing Record 31 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 2 | fortuna
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | evensk
# Processing Record 36 of Set 2 | kismayo
# Processing Record 37 of Set 2 | labelle
# Processing Record 38 of Set 2 | bairiki
# Processing Record 39 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 2 | kesennuma
# City not found. Skipping...
# Processing Record 41 of Set 2 | sao jose de ribamar
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | mahajanga
# Processing Record 44 of Set 2 | north bend
# Processing Record 45 of Set 2 | kassala
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | georgiyevskoye
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | ostrovnoy
# Processing Record 50 of Set 2 | bandar-e lengeh
# Processing Record 1 of Set 3 | port hardy
# Processing Record 2 of Set 3 | alice springs
# Processing Record 3 of Set 3 | clyde river
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | port lincoln
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | tawzar
# City not found. Skipping...
# Processing Record 8 of Set 3 | jedburgh
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | saldanha
# Processing Record 11 of Set 3 | nador
# Processing Record 12 of Set 3 | mattru
# Processing Record 13 of Set 3 | adrar
# Processing Record 14 of Set 3 | zwedru
# Processing Record 15 of Set 3 | mizpe ramon
# City not found. Skipping...
# Processing Record 16 of Set 3 | shibarghan
# City not found. Skipping...
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | padang
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | san quintin
# Processing Record 25 of Set 3 | sibolga
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | jingdezhen
# Processing Record 28 of Set 3 | kijang
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | fonte boa
# Processing Record 31 of Set 3 | hurghada
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 3 | chapais
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 3 | codrington
# Processing Record 38 of Set 3 | katsuura
# Processing Record 39 of Set 3 | krasnoselkup
# Processing Record 40 of Set 3 | ivanteyevka
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | oktyabrskiy
# Processing Record 43 of Set 3 | catia la mar
# Processing Record 44 of Set 3 | rocha
# Processing Record 45 of Set 3 | belyy yar
# Processing Record 46 of Set 3 | ussel
# Processing Record 47 of Set 3 | ballina
# Processing Record 48 of Set 3 | domoni
# Processing Record 49 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 3 | flinders
# Processing Record 1 of Set 4 | springdale
# Processing Record 2 of Set 4 | petrozavodsk
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | san patricio
# Processing Record 5 of Set 4 | dicabisagan
# Processing Record 6 of Set 4 | erzin
# Processing Record 7 of Set 4 | swinoujscie
# Processing Record 8 of Set 4 | jutai
# Processing Record 9 of Set 4 | dingzhou
# Processing Record 10 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 11 of Set 4 | saiha
# Processing Record 12 of Set 4 | isangel
# Processing Record 13 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 4 | svetlyy
# Processing Record 15 of Set 4 | port-gentil
# Processing Record 16 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 4 | rio gallegos
# Processing Record 18 of Set 4 | hami
# Processing Record 19 of Set 4 | qitaihe
# Processing Record 20 of Set 4 | uchiza
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | puerto quijarro
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | lagoa
# Processing Record 26 of Set 4 | vardo
# Processing Record 27 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 28 of Set 4 | plettenberg bay
# Processing Record 29 of Set 4 | montrose
# Processing Record 30 of Set 4 | chuy
# Processing Record 31 of Set 4 | fairbanks
# Processing Record 32 of Set 4 | ayabaca
# Processing Record 33 of Set 4 | lunenburg
# Processing Record 34 of Set 4 | iqaluit
# Processing Record 35 of Set 4 | provideniya
# Processing Record 36 of Set 4 | west fargo
# Processing Record 37 of Set 4 | marzuq
# Processing Record 38 of Set 4 | nakodar
# Processing Record 39 of Set 4 | klaksvik
# Processing Record 40 of Set 4 | sola
# Processing Record 41 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 4 | shimoda
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | kutum
# Processing Record 45 of Set 4 | seymchan
# Processing Record 46 of Set 4 | la cruz
# Processing Record 47 of Set 4 | zhob
# Processing Record 48 of Set 4 | cartagena
# Processing Record 49 of Set 4 | severo-kurilsk
# Processing Record 50 of Set 4 | chimbote
# Processing Record 1 of Set 5 | medea
# Processing Record 2 of Set 5 | makung
# City not found. Skipping...
# Processing Record 3 of Set 5 | staryy nadym
# Processing Record 4 of Set 5 | mont-dore
# Processing Record 5 of Set 5 | harper
# Processing Record 6 of Set 5 | ferrandina
# Processing Record 7 of Set 5 | upernavik
# Processing Record 8 of Set 5 | hobyo
# Processing Record 9 of Set 5 | san cristobal
# Processing Record 10 of Set 5 | bintulu
# Processing Record 11 of Set 5 | lorengau
# Processing Record 12 of Set 5 | kimbe
# Processing Record 13 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 5 | tiznit
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | racovita
# Processing Record 17 of Set 5 | anadyr
# Processing Record 18 of Set 5 | abnub
# Processing Record 19 of Set 5 | havoysund
# Processing Record 20 of Set 5 | elat
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | hovd
# Processing Record 23 of Set 5 | chokurdakh
# Processing Record 24 of Set 5 | san pedro
# Processing Record 25 of Set 5 | amapa
# Processing Record 26 of Set 5 | umm kaddadah
# Processing Record 27 of Set 5 | mporokoso
# Processing Record 28 of Set 5 | ossora
# Processing Record 29 of Set 5 | finschhafen
# Processing Record 30 of Set 5 | oriximina
# Processing Record 31 of Set 5 | timra
# Processing Record 32 of Set 5 | black forest
# Processing Record 33 of Set 5 | goderich
# Processing Record 34 of Set 5 | torbay
# Processing Record 35 of Set 5 | dudinka
# Processing Record 36 of Set 5 | moiyabana
# City not found. Skipping...
# Processing Record 37 of Set 5 | dhidhdhoo
# Processing Record 38 of Set 5 | lodja
# Processing Record 39 of Set 5 | manbij
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | mandvi
# Processing Record 42 of Set 5 | bethel
# Processing Record 43 of Set 5 | kamenka
# Processing Record 44 of Set 5 | muros
# Processing Record 45 of Set 5 | durango
# Processing Record 46 of Set 5 | necochea
# Processing Record 47 of Set 5 | ust-maya
# Processing Record 48 of Set 5 | atar
# Processing Record 49 of Set 5 | bardiyah
# Processing Record 50 of Set 5 | warmbad
# Processing Record 1 of Set 6 | presidencia roque saenz pena
# Processing Record 2 of Set 6 | morogoro
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | ocean springs
# Processing Record 5 of Set 6 | paamiut
# Processing Record 6 of Set 6 | lawrenceburg
# Processing Record 7 of Set 6 | pacatuba
# Processing Record 8 of Set 6 | deputatskiy
# Processing Record 9 of Set 6 | cherepovets
# Processing Record 10 of Set 6 | ixtapa
# Processing Record 11 of Set 6 | casper
# Processing Record 12 of Set 6 | hilo
# Processing Record 13 of Set 6 | victoria
# Processing Record 14 of Set 6 | sehwan
# Processing Record 15 of Set 6 | oussouye
# Processing Record 16 of Set 6 | vila velha
# Processing Record 17 of Set 6 | gogrial
# Processing Record 18 of Set 6 | kedougou
# Processing Record 19 of Set 6 | bambanglipuro
# Processing Record 20 of Set 6 | zima
# Processing Record 21 of Set 6 | ondjiva
# Processing Record 22 of Set 6 | sug-aksy
# City not found. Skipping...
# Processing Record 23 of Set 6 | pincehely
# Processing Record 24 of Set 6 | kingsport
# Processing Record 25 of Set 6 | quelimane
# Processing Record 26 of Set 6 | touros
# Processing Record 27 of Set 6 | kavaratti
# Processing Record 28 of Set 6 | chernyshevskiy
# Processing Record 29 of Set 6 | chuncheng
# Processing Record 30 of Set 6 | lazaro cardenas
# Processing Record 31 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 6 | hambantota
# Processing Record 33 of Set 6 | carutapera
# Processing Record 34 of Set 6 | mogadishu
# Processing Record 35 of Set 6 | mount isa
# Processing Record 36 of Set 6 | ketchikan
# Processing Record 37 of Set 6 | gao
# Processing Record 38 of Set 6 | gravdal
# Processing Record 39 of Set 6 | la ronge
# Processing Record 40 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 6 | nantucket
# Processing Record 42 of Set 6 | raudeberg
# Processing Record 43 of Set 6 | richards bay
# Processing Record 44 of Set 6 | rasskazovo
# Processing Record 45 of Set 6 | sao filipe
# Processing Record 46 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 6 | ribeira grande
# Processing Record 48 of Set 6 | sinazongwe
# Processing Record 49 of Set 6 | gamba
# Processing Record 50 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 7 | lasa
# Processing Record 2 of Set 7 | souillac
# Processing Record 3 of Set 7 | kailua
# Processing Record 4 of Set 7 | grand gaube
# Processing Record 5 of Set 7 | chernyanka
# Processing Record 6 of Set 7 | ryki
# Processing Record 7 of Set 7 | vao
# Processing Record 8 of Set 7 | jaciara
# Processing Record 9 of Set 7 | hongan
# City not found. Skipping...
# Processing Record 10 of Set 7 | phumi samraong
# City not found. Skipping...
# Processing Record 11 of Set 7 | gangakher
# Processing Record 12 of Set 7 | bajil
# Processing Record 13 of Set 7 | itapemirim
# Processing Record 14 of Set 7 | rafsanjan
# Processing Record 15 of Set 7 | ancud
# Processing Record 16 of Set 7 | biak
# Processing Record 17 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | nanortalik
# Processing Record 20 of Set 7 | katangli
# Processing Record 21 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 7 | summerside
# Processing Record 23 of Set 7 | santa cecilia
# Processing Record 24 of Set 7 | fuerte olimpo
# Processing Record 25 of Set 7 | santa maria
# Processing Record 26 of Set 7 | pingliang
# Processing Record 27 of Set 7 | stokmarknes
# Processing Record 28 of Set 7 | portland
# Processing Record 29 of Set 7 | tuatapere
# Processing Record 30 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 31 of Set 7 | cayenne
# Processing Record 32 of Set 7 | puerto asis
# Processing Record 33 of Set 7 | hearst
# Processing Record 34 of Set 7 | halifax
# Processing Record 35 of Set 7 | waingapu
# Processing Record 36 of Set 7 | longyearbyen
# Processing Record 37 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 38 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 7 | faya
# Processing Record 40 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 7 | bend
# Processing Record 42 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 7 | byron bay
# Processing Record 44 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 7 | quang ngai
# Processing Record 46 of Set 7 | beloha
# Processing Record 47 of Set 7 | komsomolskiy
# Processing Record 48 of Set 7 | sao joao da barra
# Processing Record 49 of Set 7 | casa grande
# Processing Record 50 of Set 7 | namatanai
# Processing Record 1 of Set 8 | pontes e lacerda
# Processing Record 2 of Set 8 | gazojak
# Processing Record 3 of Set 8 | reconquista
# Processing Record 4 of Set 8 | san rafael
# Processing Record 5 of Set 8 | tomatlan
# Processing Record 6 of Set 8 | borogontsy
# Processing Record 7 of Set 8 | cidreira
# Processing Record 8 of Set 8 | maniitsoq
# Processing Record 9 of Set 8 | hamilton
# Processing Record 10 of Set 8 | inuvik
# Processing Record 11 of Set 8 | san policarpo
# Processing Record 12 of Set 8 | moron
# Processing Record 13 of Set 8 | buala
# Processing Record 14 of Set 8 | rawson
# Processing Record 15 of Set 8 | neuquen
# Processing Record 16 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 8 | tinskoy
# Processing Record 18 of Set 8 | bulgan
# Processing Record 19 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 8 | tongliao
# Processing Record 21 of Set 8 | vung tau
# Processing Record 22 of Set 8 | prainha
# Processing Record 23 of Set 8 | broken hill
# Processing Record 24 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 8 | pacifica
# Processing Record 26 of Set 8 | indianola
# Processing Record 27 of Set 8 | westport
# Processing Record 28 of Set 8 | palmer
# Processing Record 29 of Set 8 | ust-kut
# Processing Record 30 of Set 8 | paragominas
# Processing Record 31 of Set 8 | xining
# Processing Record 32 of Set 8 | key largo
# Processing Record 33 of Set 8 | faanui
# Processing Record 34 of Set 8 | seybaplaya
# Processing Record 35 of Set 8 | te anau
# Processing Record 36 of Set 8 | bubaque
# Processing Record 37 of Set 8 | ponta delgada
# Processing Record 38 of Set 8 | anloga
# Processing Record 39 of Set 8 | urucara
# Processing Record 40 of Set 8 | pangai
# Processing Record 41 of Set 8 | agadir
# Processing Record 42 of Set 8 | den helder
# Processing Record 43 of Set 8 | ambilobe
# Processing Record 44 of Set 8 | tumbes
# Processing Record 45 of Set 8 | saint anthony
# Processing Record 46 of Set 8 | meadow lake
# Processing Record 47 of Set 8 | zhangye
# Processing Record 48 of Set 8 | pemba
# Processing Record 49 of Set 8 | marrakesh
# Processing Record 50 of Set 8 | varnavino
# Processing Record 1 of Set 9 | beroroha
# Processing Record 2 of Set 9 | saint-pierre
# Processing Record 3 of Set 9 | karasjok
# Processing Record 4 of Set 9 | constantine
# Processing Record 5 of Set 9 | miercurea-ciuc
# Processing Record 6 of Set 9 | ormara
# Processing Record 7 of Set 9 | honningsvag
# Processing Record 8 of Set 9 | ust-nera
# Processing Record 9 of Set 9 | togitsu
# Processing Record 10 of Set 9 | nieuw amsterdam
# Processing Record 11 of Set 9 | quatre cocos
# Processing Record 12 of Set 9 | nanakuli
# Processing Record 13 of Set 9 | naze
# Processing Record 14 of Set 9 | long beach
# Processing Record 15 of Set 9 | bermejo
# Processing Record 16 of Set 9 | mount gambier
# Processing Record 17 of Set 9 | khatima
# Processing Record 18 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 9 | bengkulu
# Processing Record 21 of Set 9 | samarai
# Processing Record 22 of Set 9 | gat
# Processing Record 23 of Set 9 | berbera
# Processing Record 24 of Set 9 | gombong
# Processing Record 25 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | kuminskiy
# Processing Record 27 of Set 9 | wattegama
# Processing Record 28 of Set 9 | mende
# Processing Record 29 of Set 9 | guastatoya
# Processing Record 30 of Set 9 | hokitika
# Processing Record 31 of Set 9 | poum
# Processing Record 32 of Set 9 | camocim
# Processing Record 33 of Set 9 | ankazoabo
# Processing Record 34 of Set 9 | gweru
# Processing Record 35 of Set 9 | vila
# Processing Record 36 of Set 9 | jensen beach
# Processing Record 37 of Set 9 | thompson
# Processing Record 38 of Set 9 | whitehorse
# Processing Record 39 of Set 9 | coos bay
# Processing Record 40 of Set 9 | calamar
# Processing Record 41 of Set 9 | yerbogachen
# Processing Record 42 of Set 9 | kruisfontein
# Processing Record 43 of Set 9 | hervey bay
# Processing Record 44 of Set 9 | khakhea
# Processing Record 45 of Set 9 | jackson
# Processing Record 46 of Set 9 | vila franca do campo
# Processing Record 47 of Set 9 | kamaishi
# Processing Record 48 of Set 9 | viedma
# Processing Record 49 of Set 9 | pella
# Processing Record 50 of Set 9 | yaya
# Processing Record 1 of Set 10 | abha
# Processing Record 2 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 3 of Set 10 | coquimbo
# Processing Record 4 of Set 10 | springbok
# Processing Record 5 of Set 10 | la plata
# Processing Record 6 of Set 10 | hirara
# Processing Record 7 of Set 10 | buzmeyin
# Processing Record 8 of Set 10 | tocopilla
# Processing Record 9 of Set 10 | ponta do sol
# Processing Record 10 of Set 10 | port blair
# Processing Record 11 of Set 10 | jomalig
# City not found. Skipping...
# Processing Record 12 of Set 10 | biloela
# Processing Record 13 of Set 10 | puerto escondido
# Processing Record 14 of Set 10 | belmonte
# Processing Record 15 of Set 10 | atherton
# Processing Record 16 of Set 10 | leh
# Processing Record 17 of Set 10 | brownwood
# Processing Record 18 of Set 10 | tufanganj
# Processing Record 19 of Set 10 | yarada
# Processing Record 20 of Set 10 | beringovskiy
# Processing Record 21 of Set 10 | brae
# Processing Record 22 of Set 10 | dingle
# Processing Record 23 of Set 10 | grindavik
# Processing Record 24 of Set 10 | kloulklubed
# Processing Record 25 of Set 10 | mitsamiouli
# Processing Record 26 of Set 10 | katherine
# Processing Record 27 of Set 10 | agadez
# Processing Record 28 of Set 10 | egvekinot
# Processing Record 29 of Set 10 | port macquarie
# Processing Record 30 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 31 of Set 10 | mucuri
# Processing Record 32 of Set 10 | alofi
# Processing Record 33 of Set 10 | nauta
# Processing Record 34 of Set 10 | jambi
# Processing Record 35 of Set 10 | piranshahr
# Processing Record 36 of Set 10 | salinopolis
# Processing Record 37 of Set 10 | rudbar
# Processing Record 38 of Set 10 | turochak
# Processing Record 39 of Set 10 | peniche
# Processing Record 40 of Set 10 | nazare
# Processing Record 41 of Set 10 | college
# Processing Record 42 of Set 10 | tazovskiy
# Processing Record 43 of Set 10 | changchun
# Processing Record 44 of Set 10 | pekalongan
# Processing Record 45 of Set 10 | bonavista
# Processing Record 46 of Set 10 | norman wells
# Processing Record 47 of Set 10 | sayyan
# Processing Record 48 of Set 10 | linxia
# Processing Record 49 of Set 10 | pundaguitan
# Processing Record 50 of Set 10 | kontagora
# Processing Record 1 of Set 11 | saint-francois
# Processing Record 2 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 11 | srednekolymsk
# Processing Record 4 of Set 11 | chake chake
# Processing Record 5 of Set 11 | yulara
# Processing Record 6 of Set 11 | porto novo
# Processing Record 7 of Set 11 | russell
# Processing Record 8 of Set 11 | stara zagora
# Processing Record 9 of Set 11 | hofn
# Processing Record 10 of Set 11 | kapit
# Processing Record 11 of Set 11 | lhokseumawe
# Processing Record 12 of Set 11 | minudasht
# Processing Record 13 of Set 11 | taywarah
# Processing Record 14 of Set 11 | brigantine
# Processing Record 15 of Set 11 | hranice
# Processing Record 16 of Set 11 | monroe
# Processing Record 17 of Set 11 | los llanos de aridane
# Processing Record 18 of Set 11 | yeniseysk
# Processing Record 19 of Set 11 | vysokogornyy
# Processing Record 20 of Set 11 | melville
# Processing Record 21 of Set 11 | aberdeen
# Processing Record 22 of Set 11 | amiens
# Processing Record 23 of Set 11 | haverfordwest
# Processing Record 24 of Set 11 | yumen
# Processing Record 25 of Set 11 | arman
# Processing Record 26 of Set 11 | port-cartier
# Processing Record 27 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 28 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | poso
# Processing Record 30 of Set 11 | kirakira
# Processing Record 31 of Set 11 | aklavik
# Processing Record 32 of Set 11 | flin flon
# Processing Record 33 of Set 11 | morondava
# Processing Record 34 of Set 11 | walvis bay
# Processing Record 35 of Set 11 | nyurba
# Processing Record 36 of Set 11 | agdam
# Processing Record 37 of Set 11 | weihai
# Processing Record 38 of Set 11 | drumnadrochit
# Processing Record 39 of Set 11 | eyl
# Processing Record 40 of Set 11 | coihaique
# Processing Record 41 of Set 11 | bati
# Processing Record 42 of Set 11 | orlik
# Processing Record 43 of Set 11 | bonnyville
# Processing Record 44 of Set 11 | bokoro
# Processing Record 45 of Set 11 | sarandi
# Processing Record 46 of Set 11 | katha
# City not found. Skipping...
# Processing Record 47 of Set 11 | makakilo city
# Processing Record 48 of Set 11 | teguise
# Processing Record 49 of Set 11 | sorong
# Processing Record 50 of Set 11 | najran
# Processing Record 1 of Set 12 | natal
# Processing Record 2 of Set 12 | the valley
# Processing Record 3 of Set 12 | khorixas
# Processing Record 4 of Set 12 | campana
# Processing Record 5 of Set 12 | yurga
# Processing Record 6 of Set 12 | glens falls
# Processing Record 7 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 12 | lixourion
# Processing Record 9 of Set 12 | balykshi
# Processing Record 10 of Set 12 | samana
# Processing Record 11 of Set 12 | saint-joseph
# Processing Record 12 of Set 12 | cativa
# Processing Record 13 of Set 12 | goya
# Processing Record 14 of Set 12 | vanimo
# Processing Record 15 of Set 12 | disna
# Processing Record 16 of Set 12 | popondetta
# Processing Record 17 of Set 12 | kununurra
# Processing Record 18 of Set 12 | pervomayskiy
# Processing Record 19 of Set 12 | pomabamba
# Processing Record 20 of Set 12 | trelew
# Processing Record 21 of Set 12 | barahona
# Processing Record 22 of Set 12 | phalia
# Processing Record 23 of Set 12 | oeiras do para
# Processing Record 24 of Set 12 | manaure
# Processing Record 25 of Set 12 | magistralnyy
# Processing Record 26 of Set 12 | general roca
# Processing Record 27 of Set 12 | korla
# Processing Record 28 of Set 12 | sovetskiy
# Processing Record 29 of Set 12 | otavi
# Processing Record 30 of Set 12 | veinticinco de mayo
# Processing Record 31 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 32 of Set 12 | margate
# Processing Record 33 of Set 12 | vostok
# Processing Record 34 of Set 12 | kieta
# Processing Record 35 of Set 12 | ambovombe
# Processing Record 36 of Set 12 | decatur
# Processing Record 37 of Set 12 | wahlern
# Processing Record 38 of Set 12 | burnie
# Processing Record 39 of Set 12 | turukhansk
# Processing Record 40 of Set 12 | rio grande
# Processing Record 41 of Set 12 | yilan
# Processing Record 42 of Set 12 | hit
# Processing Record 43 of Set 12 | bodden town
# Processing Record 44 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 12 | praya
# Processing Record 46 of Set 12 | mareeba
# Processing Record 47 of Set 12 | miles city
# Processing Record 48 of Set 12 | fergus
# Processing Record 49 of Set 12 | smithers
# Processing Record 50 of Set 12 | tembisa
# Processing Record 1 of Set 13 | kalianget
# Processing Record 2 of Set 13 | la solana
# Processing Record 3 of Set 13 | manggar
# Processing Record 4 of Set 13 | valparaiso
# Processing Record 5 of Set 13 | genhe
# Processing Record 6 of Set 13 | nago
# Processing Record 7 of Set 13 | mitu
# Processing Record 8 of Set 13 | dalvik
# Processing Record 9 of Set 13 | kungurtug
# Processing Record 10 of Set 13 | puerto cabezas
# Processing Record 11 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 13 | terra santa
# Processing Record 13 of Set 13 | coahuayana
# Processing Record 14 of Set 13 | sorland
# Processing Record 15 of Set 13 | skjervoy
# Processing Record 16 of Set 13 | chifeng
# Processing Record 17 of Set 13 | rorvik
# Processing Record 18 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 13 | barcelos
# Processing Record 20 of Set 13 | big spring
# Processing Record 21 of Set 13 | broome
# Processing Record 22 of Set 13 | laguna
# Processing Record 23 of Set 13 | ambikapur
# Processing Record 24 of Set 13 | de-kastri
# Processing Record 25 of Set 13 | calama
# Processing Record 26 of Set 13 | verkhnetulomskiy
# Processing Record 27 of Set 13 | olafsvik
# Processing Record 28 of Set 13 | san angelo
# Processing Record 29 of Set 13 | malakal
# Processing Record 30 of Set 13 | sainte-maxime
# Processing Record 31 of Set 13 | asyut
# Processing Record 32 of Set 13 | baruun-urt
# Processing Record 33 of Set 13 | esna
# Processing Record 34 of Set 13 | ati
# Processing Record 35 of Set 13 | sterling
# Processing Record 36 of Set 13 | mercedes
# Processing Record 37 of Set 13 | kaduqli
# Processing Record 38 of Set 13 | aswan
# Processing Record 39 of Set 13 | bressanone
# Processing Record 40 of Set 13 | jiangyou
# Processing Record 41 of Set 13 | nouakchott
# Processing Record 42 of Set 13 | orahovac
# Processing Record 43 of Set 13 | namie
# Processing Record 44 of Set 13 | vallenar
# Processing Record 45 of Set 13 | mehamn
# Processing Record 46 of Set 13 | nagua
# Processing Record 47 of Set 13 | ahipara
# Processing Record 48 of Set 13 | fukue
# Processing Record 49 of Set 13 | sinjar
# Processing Record 50 of Set 13 | meulaboh
# Processing Record 1 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 14 | diffa
# Processing Record 3 of Set 14 | orbetello
# Processing Record 4 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 14 | umba
# Processing Record 6 of Set 14 | tarko-sale
# Processing Record 7 of Set 14 | birin
# Processing Record 8 of Set 14 | buraydah
# Processing Record 9 of Set 14 | mubi
# Processing Record 10 of Set 14 | saint-leu
# Processing Record 11 of Set 14 | seminole
# Processing Record 12 of Set 14 | luwuk
# Processing Record 13 of Set 14 | oranjemund
# Processing Record 14 of Set 14 | novobessergenevka
# Processing Record 15 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 14 | rethimnon
# Processing Record 17 of Set 14 | chiang rai
# Processing Record 18 of Set 14 | payson
# Processing Record 19 of Set 14 | pucara
# Processing Record 20 of Set 14 | leningradskiy
# Processing Record 21 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 22 of Set 14 | manzanillo
# Processing Record 23 of Set 14 | kidal
# Processing Record 24 of Set 14 | bria
# Processing Record 25 of Set 14 | tomohon
# Processing Record 26 of Set 14 | lamar
# Processing Record 27 of Set 14 | ler
# Processing Record 28 of Set 14 | kaliua
# Processing Record 29 of Set 14 | novyy urengoy
# Processing Record 30 of Set 14 | chabahar
# Processing Record 31 of Set 14 | sehithwa
# Processing Record 32 of Set 14 | nam som
# Processing Record 33 of Set 14 | maragogi
# Processing Record 34 of Set 14 | wageningen
# Processing Record 35 of Set 14 | krasnokamensk
# Processing Record 36 of Set 14 | sabha
# Processing Record 37 of Set 14 | zhigansk
# Processing Record 38 of Set 14 | vestmanna
# Processing Record 39 of Set 14 | berlevag
# Processing Record 40 of Set 14 | mugumu
# Processing Record 41 of Set 14 | pasco
# Processing Record 42 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 43 of Set 14 | unye
# City not found. Skipping...
# Processing Record 44 of Set 14 | muisne
# Processing Record 45 of Set 14 | nome
# Processing Record 46 of Set 14 | shar
# Processing Record 47 of Set 14 | tautira
# Processing Record 48 of Set 14 | sarangani
# Processing Record 49 of Set 14 | miramar
# Processing Record 50 of Set 14 | northam
# Processing Record 1 of Set 15 | aneza
# Processing Record 2 of Set 15 | forest
# Processing Record 3 of Set 15 | aracatuba
# Processing Record 4 of Set 15 | wakkanai
# Processing Record 5 of Set 15 | high level
# Processing Record 6 of Set 15 | enid
# Processing Record 7 of Set 15 | kaeo
# Processing Record 8 of Set 15 | surskoye
# Processing Record 9 of Set 15 | dalmatovo
# Processing Record 10 of Set 15 | borba
# Processing Record 11 of Set 15 | fort nelson
# Processing Record 12 of Set 15 | hvide sande
# Processing Record 13 of Set 15 | aguimes
# Processing Record 14 of Set 15 | praia
# Processing Record 15 of Set 15 | cefalu
# Processing Record 16 of Set 15 | shimanovsk
# Processing Record 17 of Set 15 | ternate
# Processing Record 18 of Set 15 | puerto el triunfo
# Processing Record 19 of Set 15 | bathsheba
# Processing Record 20 of Set 15 | sao jose da coroa grande
# Processing Record 21 of Set 15 | vannes
# Processing Record 22 of Set 15 | kharovsk
# Processing Record 23 of Set 15 | mastung
# Processing Record 24 of Set 15 | altay
# Processing Record 25 of Set 15 | kargasok
# Processing Record 26 of Set 15 | la ciotat
# Processing Record 27 of Set 15 | yeppoon
# Processing Record 28 of Set 15 | anori
# Processing Record 29 of Set 15 | tuburan
# Processing Record 30 of Set 15 | sfantu gheorghe
# Processing Record 31 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 32 of Set 15 | goma
# Processing Record 33 of Set 15 | dunedin
# Processing Record 34 of Set 15 | sompeta
# Processing Record 35 of Set 15 | tongling
# Processing Record 36 of Set 15 | ukiah
# Processing Record 37 of Set 15 | ewa beach
# Processing Record 38 of Set 15 | korba
# Processing Record 39 of Set 15 | edmond
# Processing Record 40 of Set 15 | wamba
# Processing Record 41 of Set 15 | bogande
# Processing Record 42 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 15 | liwale
# Processing Record 44 of Set 15 | okahandja
# Processing Record 45 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 15 | mangrol
# Processing Record 47 of Set 15 | oranjestad
# Processing Record 48 of Set 15 | udachnyy
# Processing Record 49 of Set 15 | gayny
# Processing Record 50 of Set 15 | kuching
# Processing Record 1 of Set 16 | tarboro
# Processing Record 2 of Set 16 | tiverton
# Processing Record 3 of Set 16 | bosaso
# Processing Record 4 of Set 16 | riyadh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth -33.9180   25.5701     68.31        99           3
# 1         Awjilah  29.1081   21.2869     50.94        65           2
# 2          Atuona  -9.8000 -139.0333     78.96        76          92
# 3         Kavieng  -2.5744  150.7967     84.56        68          86
# 4          Avarua -21.2078 -159.7750     78.85        83          75
# 5           Kapaa  22.0752 -159.3190     79.12        77          75
# 6      Butaritari   3.0707  172.7902     80.22        79         100
# 7           Sitka  57.0531 -135.3300     39.09        81         100
# 8         Dolores -36.3132  -57.6792     65.79        93          10
# 9     Walla Walla  46.0646 -118.3430     35.51        69           0
#
#    Wind Speed  Current Weather Country
# 0        3.62        clear sky      ZA
# 1       14.36        clear sky      LY
# 2       22.03  overcast clouds      PF
# 3        8.16  overcast clouds      PG
# 4       17.27       light rain      CK
# 5       10.36       light rain      US
# 6       16.82       light rain      KI
# 7       16.11    moderate rain      US
# 8        7.70       light rain      AR
# 9        5.01        clear sky      US

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Weather', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns=["City", "Country","Lat","Lng", "Max Temp","Humidity","Cloudiness","Wind Speed","Current Weather",]


# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_columns]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth      ZA -33.9180   25.5701     68.31        99           3
# 1         Awjilah      LY  29.1081   21.2869     50.94        65           2
# 2          Atuona      PF  -9.8000 -139.0333     78.96        76          92
# 3         Kavieng      PG  -2.5744  150.7967     84.56        68          86
# 4          Avarua      CK -21.2078 -159.7750     78.85        83          75
# 5           Kapaa      US  22.0752 -159.3190     79.12        77          75
# 6      Butaritari      KI   3.0707  172.7902     80.22        79         100
# 7           Sitka      US  57.0531 -135.3300     39.09        81         100
# 8         Dolores      AR -36.3132  -57.6792     65.79        93          10
# 9     Walla Walla      US  46.0646 -118.3430     35.51        69           0
#
#    Wind Speed  Current Weather
# 0        3.62        clear sky
# 1       14.36        clear sky
# 2       22.03  overcast clouds
# 3        8.16  overcast clouds
# 4       17.27       light rain
# 5       10.36       light rain
# 6       16.82       light rain
# 7       16.11    moderate rain
# 8        7.70       light rain
# 9        5.01        clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                object
# Country             object
# Lat                float64
# Lng                float64
# Max Temp           float64
# Humidity             int64
# Cloudiness           int64
# Wind Speed         float64
# Current Weather     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
file_name="WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(file_name, index_label="City_ID")
