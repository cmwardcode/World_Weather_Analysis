# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bf55234342c0b01c5da022ca2420fb20

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bf55234342c0b01c5da022ca2420fb20&q=Boston

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform (low=-90.00, high=90.00, size=2000)
lngs = np.random.uniform (low=-180.00, high=180.00, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
#Creating a list for lat and longs
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# Create an empty list 
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#Create Counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather['sys']['country']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                    
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | soto la marina
# Processing Record 8 of Set 1 | krasnyy chikoy
# Processing Record 9 of Set 1 | tongliao
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | bengkulu
# Processing Record 12 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | puerto escondido
# Processing Record 15 of Set 1 | rawson
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | phu ly
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | erzin
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | la asuncion
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | malur
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | victoria
# Processing Record 31 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 1 | luganville
# Processing Record 33 of Set 1 | qufu
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | burica
# City not found. Skipping...
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | sitka
# Processing Record 39 of Set 1 | kashan
# Processing Record 40 of Set 1 | alpena
# Processing Record 41 of Set 1 | praia
# Processing Record 42 of Set 1 | bubaque
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | bereda
# Processing Record 45 of Set 1 | souillac
# Processing Record 46 of Set 1 | borodino
# Processing Record 47 of Set 1 | saldanha
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | vulturu
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | shubarkuduk
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | nishihara
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | poso
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | arlit
# Processing Record 12 of Set 2 | luderitz
# Processing Record 13 of Set 2 | manado
# Processing Record 14 of Set 2 | flinders
# Processing Record 15 of Set 2 | daru
# Processing Record 16 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 18 of Set 2 | namibe
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | lata
# Processing Record 21 of Set 2 | marrakesh
# Processing Record 22 of Set 2 | namatanai
# Processing Record 23 of Set 2 | coihaique
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | primo tapia
# Processing Record 26 of Set 2 | litoral del san juan
# City not found. Skipping...
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | barreirinhas
# Processing Record 30 of Set 2 | ananas
# Processing Record 31 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 2 | taoudenni
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | ishim
# Processing Record 35 of Set 2 | kudinovo
# Processing Record 36 of Set 2 | asasa
# Processing Record 37 of Set 2 | torbay
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | turukhansk
# Processing Record 41 of Set 2 | bundaberg
# Processing Record 42 of Set 2 | peleduy
# Processing Record 43 of Set 2 | lompoc
# Processing Record 44 of Set 2 | buraydah
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | bontang
# Processing Record 1 of Set 3 | zinacantan
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | lorengau
# Processing Record 4 of Set 3 | erzincan
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | vardo
# Processing Record 7 of Set 3 | sangmelima
# Processing Record 8 of Set 3 | aktash
# Processing Record 9 of Set 3 | antalaha
# Processing Record 10 of Set 3 | nome
# Processing Record 11 of Set 3 | santa maria
# Processing Record 12 of Set 3 | srednekolymsk
# Processing Record 13 of Set 3 | iroquois falls
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | ola
# Processing Record 16 of Set 3 | mehamn
# Processing Record 17 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 3 | wagar
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | byron bay
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 3 | aitape
# Processing Record 24 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 3 | geraldton
# Processing Record 26 of Set 3 | shostka
# Processing Record 27 of Set 3 | komsomolskiy
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | vanavara
# Processing Record 30 of Set 3 | rensvik
# Processing Record 31 of Set 3 | salalah
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | tres arroyos
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | padang
# Processing Record 36 of Set 3 | bluff
# Processing Record 37 of Set 3 | clonakilty
# Processing Record 38 of Set 3 | puerto ayora
# Processing Record 39 of Set 3 | turtkul
# City not found. Skipping...
# Processing Record 40 of Set 3 | arona
# Processing Record 41 of Set 3 | paracuru
# Processing Record 42 of Set 3 | kulhudhuffushi
# Processing Record 43 of Set 3 | chumikan
# Processing Record 44 of Set 3 | quatre cocos
# Processing Record 45 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 3 | kahului
# Processing Record 47 of Set 3 | bochnia
# Processing Record 48 of Set 3 | antofagasta
# Processing Record 49 of Set 3 | te anau
# Processing Record 50 of Set 3 | jiuquan
# Processing Record 1 of Set 4 | bairnsdale
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | kodiak
# Processing Record 5 of Set 4 | kruisfontein
# Processing Record 6 of Set 4 | prince rupert
# Processing Record 7 of Set 4 | fortuna
# Processing Record 8 of Set 4 | liaozhong
# Processing Record 9 of Set 4 | buala
# Processing Record 10 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 4 | santa cruz
# Processing Record 12 of Set 4 | grand forks
# Processing Record 13 of Set 4 | gyomaendrod
# Processing Record 14 of Set 4 | fort nelson
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | roches noires
# City not found. Skipping...
# Processing Record 17 of Set 4 | tornio
# Processing Record 18 of Set 4 | kalmunai
# Processing Record 19 of Set 4 | ostrovnoy
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | gopalpur
# Processing Record 22 of Set 4 | haapiti
# Processing Record 23 of Set 4 | asau
# Processing Record 24 of Set 4 | port lincoln
# Processing Record 25 of Set 4 | upington
# Processing Record 26 of Set 4 | verkhovazhye
# Processing Record 27 of Set 4 | meinung
# City not found. Skipping...
# Processing Record 28 of Set 4 | boa vista
# Processing Record 29 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 4 | parrita
# Processing Record 31 of Set 4 | lazaro cardenas
# Processing Record 32 of Set 4 | paraiso
# Processing Record 33 of Set 4 | port hedland
# Processing Record 34 of Set 4 | isangel
# Processing Record 35 of Set 4 | sorland
# Processing Record 36 of Set 4 | ilulissat
# Processing Record 37 of Set 4 | tandil
# Processing Record 38 of Set 4 | poya
# Processing Record 39 of Set 4 | talnakh
# Processing Record 40 of Set 4 | cascais
# Processing Record 41 of Set 4 | estelle
# Processing Record 42 of Set 4 | sao felix do xingu
# Processing Record 43 of Set 4 | eura
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | dzhebariki-khaya
# Processing Record 46 of Set 4 | doha
# Processing Record 47 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 4 | vila velha
# Processing Record 49 of Set 4 | pacific grove
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | trat
# Processing Record 2 of Set 5 | asmara
# Processing Record 3 of Set 5 | bathsheba
# Processing Record 4 of Set 5 | yilan
# Processing Record 5 of Set 5 | olafsvik
# Processing Record 6 of Set 5 | kazachinskoye
# Processing Record 7 of Set 5 | tefe
# Processing Record 8 of Set 5 | thompson
# Processing Record 9 of Set 5 | juneau
# Processing Record 10 of Set 5 | banda aceh
# Processing Record 11 of Set 5 | sivaki
# Processing Record 12 of Set 5 | leningradskiy
# Processing Record 13 of Set 5 | humaita
# Processing Record 14 of Set 5 | kaoma
# Processing Record 15 of Set 5 | shirokiy
# Processing Record 16 of Set 5 | san jose
# Processing Record 17 of Set 5 | sabang
# Processing Record 18 of Set 5 | corralillo
# Processing Record 19 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 21 of Set 5 | aykhal
# Processing Record 22 of Set 5 | berlevag
# Processing Record 23 of Set 5 | rathenow
# Processing Record 24 of Set 5 | ulladulla
# Processing Record 25 of Set 5 | abha
# Processing Record 26 of Set 5 | bilibino
# Processing Record 27 of Set 5 | bocas del toro
# Processing Record 28 of Set 5 | gigmoto
# Processing Record 29 of Set 5 | hargeysa
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | ripky
# Processing Record 32 of Set 5 | hasaki
# Processing Record 33 of Set 5 | nyimba
# Processing Record 34 of Set 5 | pangnirtung
# Processing Record 35 of Set 5 | severo-kurilsk
# Processing Record 36 of Set 5 | stromness
# Processing Record 37 of Set 5 | acapulco
# Processing Record 38 of Set 5 | madimba
# Processing Record 39 of Set 5 | scarborough
# Processing Record 40 of Set 5 | high level
# Processing Record 41 of Set 5 | russell
# Processing Record 42 of Set 5 | baykit
# Processing Record 43 of Set 5 | malanje
# Processing Record 44 of Set 5 | clyde river
# Processing Record 45 of Set 5 | kismayo
# Processing Record 46 of Set 5 | batagay
# Processing Record 47 of Set 5 | tuatapere
# Processing Record 48 of Set 5 | kendari
# Processing Record 49 of Set 5 | atar
# Processing Record 50 of Set 5 | dawlatabad
# Processing Record 1 of Set 6 | batavia
# Processing Record 2 of Set 6 | shubarshi
# Processing Record 3 of Set 6 | filingue
# Processing Record 4 of Set 6 | pangai
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | anadyr
# Processing Record 7 of Set 6 | ayan
# Processing Record 8 of Set 6 | verkhnevilyuysk
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 6 | kijang
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | camacha
# Processing Record 15 of Set 6 | klaksvik
# Processing Record 16 of Set 6 | obama
# Processing Record 17 of Set 6 | hofn
# Processing Record 18 of Set 6 | san cristobal
# Processing Record 19 of Set 6 | mount gambier
# Processing Record 20 of Set 6 | santa isabel do rio negro
# Processing Record 21 of Set 6 | zhigansk
# Processing Record 22 of Set 6 | ruteng
# Processing Record 23 of Set 6 | cherskiy
# Processing Record 24 of Set 6 | narsaq
# Processing Record 25 of Set 6 | steinbach
# Processing Record 26 of Set 6 | marakkanam
# Processing Record 27 of Set 6 | gardez
# Processing Record 28 of Set 6 | glens falls
# Processing Record 29 of Set 6 | kavaratti
# Processing Record 30 of Set 6 | saskylakh
# Processing Record 31 of Set 6 | puerto quijarro
# Processing Record 32 of Set 6 | songjianghe
# Processing Record 33 of Set 6 | abnub
# Processing Record 34 of Set 6 | sao filipe
# Processing Record 35 of Set 6 | aklavik
# Processing Record 36 of Set 6 | egvekinot
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | suntar
# Processing Record 39 of Set 6 | la sarre
# Processing Record 40 of Set 6 | cam ranh
# Processing Record 41 of Set 6 | qorveh
# Processing Record 42 of Set 6 | corn island
# Processing Record 43 of Set 6 | guerrero negro
# Processing Record 44 of Set 6 | bolu
# Processing Record 45 of Set 6 | cuamba
# Processing Record 46 of Set 6 | toora-khem
# Processing Record 47 of Set 6 | vostok
# Processing Record 48 of Set 6 | ngaoundere
# Processing Record 49 of Set 6 | ishigaki
# Processing Record 50 of Set 6 | roquetas de mar
# Processing Record 1 of Set 7 | methoni
# Processing Record 2 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 7 | okhotsk
# Processing Record 4 of Set 7 | beira
# Processing Record 5 of Set 7 | birao
# Processing Record 6 of Set 7 | radcliff
# Processing Record 7 of Set 7 | san patricio
# Processing Record 8 of Set 7 | kasongo-lunda
# Processing Record 9 of Set 7 | sept-iles
# Processing Record 10 of Set 7 | taga dzong
# City not found. Skipping...
# Processing Record 11 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 12 of Set 7 | sampang
# Processing Record 13 of Set 7 | valdivia
# Processing Record 14 of Set 7 | dolores
# Processing Record 15 of Set 7 | scottsbluff
# Processing Record 16 of Set 7 | tak bai
# Processing Record 17 of Set 7 | garowe
# Processing Record 18 of Set 7 | yoshida
# Processing Record 19 of Set 7 | tessalit
# Processing Record 20 of Set 7 | alvarado
# Processing Record 21 of Set 7 | naze
# Processing Record 22 of Set 7 | karratha
# Processing Record 23 of Set 7 | san carlos de bariloche
# Processing Record 24 of Set 7 | college
# Processing Record 25 of Set 7 | olavarria
# Processing Record 26 of Set 7 | poronaysk
# Processing Record 27 of Set 7 | safford
# Processing Record 28 of Set 7 | mandiana
# Processing Record 29 of Set 7 | jalu
# Processing Record 30 of Set 7 | acarau
# Processing Record 31 of Set 7 | walvis bay
# Processing Record 32 of Set 7 | washington
# Processing Record 33 of Set 7 | saint george
# Processing Record 34 of Set 7 | san juan
# Processing Record 35 of Set 7 | broken hill
# Processing Record 36 of Set 7 | kieta
# Processing Record 37 of Set 7 | misratah
# Processing Record 38 of Set 7 | otavi
# Processing Record 39 of Set 7 | pisco
# Processing Record 40 of Set 7 | ancud
# Processing Record 41 of Set 7 | norilsk
# Processing Record 42 of Set 7 | palimbang
# Processing Record 43 of Set 7 | lewisporte
# Processing Record 44 of Set 7 | najran
# Processing Record 45 of Set 7 | valley city
# Processing Record 46 of Set 7 | caravelas
# Processing Record 47 of Set 7 | semey
# Processing Record 48 of Set 7 | kanchanaburi
# Processing Record 49 of Set 7 | cockburn town
# Processing Record 50 of Set 7 | jiwani
# Processing Record 1 of Set 8 | bambous virieux
# Processing Record 2 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 8 | kingston
# Processing Record 4 of Set 8 | port-gentil
# Processing Record 5 of Set 8 | berbera
# Processing Record 6 of Set 8 | springbok
# Processing Record 7 of Set 8 | dehui
# Processing Record 8 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 8 | markova
# Processing Record 10 of Set 8 | vangaindrano
# Processing Record 11 of Set 8 | dingle
# Processing Record 12 of Set 8 | hambantota
# Processing Record 13 of Set 8 | burnie
# Processing Record 14 of Set 8 | talcahuano
# Processing Record 15 of Set 8 | mitsamiouli
# Processing Record 16 of Set 8 | port-cartier
# Processing Record 17 of Set 8 | kailua
# Processing Record 18 of Set 8 | marsh harbour
# Processing Record 19 of Set 8 | nizhniy kuranakh
# Processing Record 20 of Set 8 | ust-koksa
# Processing Record 21 of Set 8 | ribeira grande
# Processing Record 22 of Set 8 | sobolevo
# Processing Record 23 of Set 8 | maniitsoq
# Processing Record 24 of Set 8 | bien unido
# Processing Record 25 of Set 8 | galesong
# Processing Record 26 of Set 8 | bukowno
# Processing Record 27 of Set 8 | hamadan
# Processing Record 28 of Set 8 | deputatskiy
# Processing Record 29 of Set 8 | ossora
# Processing Record 30 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 31 of Set 8 | sembakung
# Processing Record 32 of Set 8 | wanning
# Processing Record 33 of Set 8 | khorixas
# Processing Record 34 of Set 8 | elizabeth city
# Processing Record 35 of Set 8 | saint-philippe
# Processing Record 36 of Set 8 | bamenda
# Processing Record 37 of Set 8 | rocha
# Processing Record 38 of Set 8 | kudahuvadhoo
# Processing Record 39 of Set 8 | shache
# Processing Record 40 of Set 8 | richards bay
# Processing Record 41 of Set 8 | huilong
# Processing Record 42 of Set 8 | dauriya
# Processing Record 43 of Set 8 | los llanos de aridane
# Processing Record 44 of Set 8 | henties bay
# Processing Record 45 of Set 8 | dakar
# Processing Record 46 of Set 8 | malakal
# Processing Record 47 of Set 8 | meulaboh
# Processing Record 48 of Set 8 | tigil
# Processing Record 49 of Set 8 | kamakwie
# Processing Record 50 of Set 8 | kedrovyy
# Processing Record 1 of Set 9 | vitim
# Processing Record 2 of Set 9 | cap malheureux
# Processing Record 3 of Set 9 | maningrida
# Processing Record 4 of Set 9 | vrangel
# Processing Record 5 of Set 9 | trincomalee
# Processing Record 6 of Set 9 | sassandra
# Processing Record 7 of Set 9 | yumen
# Processing Record 8 of Set 9 | aripuana
# Processing Record 9 of Set 9 | ouesso
# Processing Record 10 of Set 9 | beberibe
# Processing Record 11 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 9 | roald
# Processing Record 13 of Set 9 | adeje
# Processing Record 14 of Set 9 | baie-saint-paul
# Processing Record 15 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 16 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 9 | key west
# Processing Record 18 of Set 9 | lavrentiya
# Processing Record 19 of Set 9 | rundu
# Processing Record 20 of Set 9 | zhanaozen
# Processing Record 21 of Set 9 | callaway
# Processing Record 22 of Set 9 | hamilton
# Processing Record 23 of Set 9 | tecoanapa
# Processing Record 24 of Set 9 | paamiut
# Processing Record 25 of Set 9 | solnechnyy
# Processing Record 26 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 9 | santa ana
# Processing Record 28 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 29 of Set 9 | benguela
# Processing Record 30 of Set 9 | gallup
# Processing Record 31 of Set 9 | san ramon
# Processing Record 32 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 33 of Set 9 | peno
# Processing Record 34 of Set 9 | mayumba
# Processing Record 35 of Set 9 | tatawin
# Processing Record 36 of Set 9 | clifton
# Processing Record 37 of Set 9 | dunedin
# Processing Record 38 of Set 9 | tawau
# Processing Record 39 of Set 9 | mount isa
# Processing Record 40 of Set 9 | galle
# Processing Record 41 of Set 9 | hailar
# Processing Record 42 of Set 9 | honiara
# Processing Record 43 of Set 9 | nouadhibou
# Processing Record 44 of Set 9 | bethel
# Processing Record 45 of Set 9 | inuvik
# Processing Record 46 of Set 9 | leh
# Processing Record 47 of Set 9 | saint-augustin
# Processing Record 48 of Set 9 | mareeba
# Processing Record 49 of Set 9 | beringovskiy
# Processing Record 50 of Set 9 | nador
# Processing Record 1 of Set 10 | winnemucca
# Processing Record 2 of Set 10 | anloga
# Processing Record 3 of Set 10 | biak
# Processing Record 4 of Set 10 | clarence town
# Processing Record 5 of Set 10 | humberto de campos
# Processing Record 6 of Set 10 | loralai
# Processing Record 7 of Set 10 | kodinsk
# Processing Record 8 of Set 10 | dom pedrito
# Processing Record 9 of Set 10 | gayny
# Processing Record 10 of Set 10 | ocean city
# Processing Record 11 of Set 10 | lamu
# Processing Record 12 of Set 10 | gardner
# Processing Record 13 of Set 10 | sumedang
# Processing Record 14 of Set 10 | duz
# City not found. Skipping...
# Processing Record 15 of Set 10 | cienfuegos
# Processing Record 16 of Set 10 | fukue
# Processing Record 17 of Set 10 | amga
# Processing Record 18 of Set 10 | gondar
# Processing Record 19 of Set 10 | port moresby
# Processing Record 20 of Set 10 | cabildo
# Processing Record 21 of Set 10 | half moon bay
# Processing Record 22 of Set 10 | tromso
# Processing Record 23 of Set 10 | verkhoyansk
# Processing Record 24 of Set 10 | ifakara
# Processing Record 25 of Set 10 | poum
# Processing Record 26 of Set 10 | vermilion
# Processing Record 27 of Set 10 | bay roberts
# Processing Record 28 of Set 10 | soyo
# Processing Record 29 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 10 | dyurtyuli
# Processing Record 31 of Set 10 | monkey bay
# Processing Record 32 of Set 10 | katete
# Processing Record 33 of Set 10 | murgab
# Processing Record 34 of Set 10 | oistins
# Processing Record 35 of Set 10 | rorvik
# Processing Record 36 of Set 10 | japura
# Processing Record 37 of Set 10 | thinadhoo
# Processing Record 38 of Set 10 | onguday
# Processing Record 39 of Set 10 | aden
# Processing Record 40 of Set 10 | vila franca do campo
# Processing Record 41 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 10 | itarema
# Processing Record 43 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 10 | sao joao da barra
# Processing Record 45 of Set 10 | camabatela
# Processing Record 46 of Set 10 | anito
# Processing Record 47 of Set 10 | svetlaya
# Processing Record 48 of Set 10 | ambilobe
# Processing Record 49 of Set 10 | provideniya
# Processing Record 50 of Set 10 | laguna
# Processing Record 1 of Set 11 | lagoa
# Processing Record 2 of Set 11 | aswan
# Processing Record 3 of Set 11 | asfi
# Processing Record 4 of Set 11 | bilma
# Processing Record 5 of Set 11 | lagos
# Processing Record 6 of Set 11 | ketchikan
# Processing Record 7 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 8 of Set 11 | chifeng
# Processing Record 9 of Set 11 | alamosa
# Processing Record 10 of Set 11 | xacmaz
# Processing Record 11 of Set 11 | khani
# Processing Record 12 of Set 11 | jizan
# Processing Record 13 of Set 11 | providencia
# Processing Record 14 of Set 11 | haines junction
# Processing Record 15 of Set 11 | mamou
# Processing Record 16 of Set 11 | conde
# Processing Record 17 of Set 11 | kenai
# Processing Record 18 of Set 11 | camalu
# Processing Record 19 of Set 11 | marzuq
# Processing Record 20 of Set 11 | makokou
# Processing Record 21 of Set 11 | vilyuysk
# Processing Record 22 of Set 11 | lang son
# Processing Record 23 of Set 11 | parabel
# Processing Record 24 of Set 11 | zaozhuang
# Processing Record 25 of Set 11 | san juan del cesar
# Processing Record 26 of Set 11 | grass valley
# Processing Record 27 of Set 11 | salamanca
# Processing Record 28 of Set 11 | tel aviv-yafo
# Processing Record 29 of Set 11 | vila
# Processing Record 30 of Set 11 | manta
# Processing Record 31 of Set 11 | morshansk
# Processing Record 32 of Set 11 | yulara
# Processing Record 33 of Set 11 | tautira
# Processing Record 34 of Set 11 | ouadda
# Processing Record 35 of Set 11 | alofi
# Processing Record 36 of Set 11 | khash
# Processing Record 37 of Set 11 | merauke
# Processing Record 38 of Set 11 | roma
# Processing Record 39 of Set 11 | grand gaube
# Processing Record 40 of Set 11 | borogontsy
# Processing Record 41 of Set 11 | eyl
# Processing Record 42 of Set 11 | brae
# Processing Record 43 of Set 11 | iqaluit
# Processing Record 44 of Set 11 | altus
# Processing Record 45 of Set 11 | mantua
# Processing Record 46 of Set 11 | batemans bay
# Processing Record 47 of Set 11 | algiers
# Processing Record 48 of Set 11 | kirakira
# Processing Record 49 of Set 11 | makaha
# Processing Record 50 of Set 11 | opuwo
# Processing Record 1 of Set 12 | umm kaddadah
# Processing Record 2 of Set 12 | kota
# Processing Record 3 of Set 12 | anchorage
# Processing Record 4 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 12 | kirs
# Processing Record 6 of Set 12 | grindavik
# Processing Record 7 of Set 12 | port keats
# Processing Record 8 of Set 12 | payakumbuh
# Processing Record 9 of Set 12 | demyansk
# Processing Record 10 of Set 12 | aporawan
# City not found. Skipping...
# Processing Record 11 of Set 12 | yining
# Processing Record 12 of Set 12 | pathein
# Processing Record 13 of Set 12 | takab
# Processing Record 14 of Set 12 | festus
# Processing Record 15 of Set 12 | amudat
# Processing Record 16 of Set 12 | codrington
# Processing Record 17 of Set 12 | bainbridge
# Processing Record 18 of Set 12 | saint-francois
# Processing Record 19 of Set 12 | telenesti
# Processing Record 20 of Set 12 | irbit
# Processing Record 21 of Set 12 | rudnogorsk
# Processing Record 22 of Set 12 | birjand
# Processing Record 23 of Set 12 | carutapera
# Processing Record 24 of Set 12 | bolobo
# Processing Record 25 of Set 12 | maun
# Processing Record 26 of Set 12 | ugoofaaru
# Processing Record 27 of Set 12 | kanniyakumari
# Processing Record 28 of Set 12 | katsuura
# Processing Record 29 of Set 12 | okato
# Processing Record 30 of Set 12 | fontem
# Processing Record 31 of Set 12 | kuytun
# Processing Record 32 of Set 12 | le moule
# Processing Record 33 of Set 12 | pandhurna
# Processing Record 34 of Set 12 | vanimo
# Processing Record 35 of Set 12 | kholodnyy
# Processing Record 36 of Set 12 | ilhabela
# Processing Record 37 of Set 12 | inhambane
# Processing Record 38 of Set 12 | nongstoin
# Processing Record 39 of Set 12 | hammerfest
# Processing Record 40 of Set 12 | portland
# Processing Record 41 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 42 of Set 12 | rovnoye
# Processing Record 43 of Set 12 | svirsk
# Processing Record 44 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 45 of Set 12 | villazon
# Processing Record 46 of Set 12 | kapit
# Processing Record 47 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 12 | bowen
# Processing Record 49 of Set 12 | benghazi
# Processing Record 50 of Set 12 | pimentel
# Processing Record 1 of Set 13 | willmar
# Processing Record 2 of Set 13 | avera
# Processing Record 3 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 13 | hami
# Processing Record 5 of Set 13 | shelburne
# Processing Record 6 of Set 13 | teguldet
# Processing Record 7 of Set 13 | glasgow
# Processing Record 8 of Set 13 | tura
# Processing Record 9 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 10 of Set 13 | cosala
# Processing Record 11 of Set 13 | mnogovershinnyy
# Processing Record 12 of Set 13 | curup
# Processing Record 13 of Set 13 | sambava
# Processing Record 14 of Set 13 | gornopravdinsk
# Processing Record 15 of Set 13 | kayes
# Processing Record 16 of Set 13 | sechura
# Processing Record 17 of Set 13 | la ferte-bernard
# Processing Record 18 of Set 13 | brigantine
# Processing Record 19 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 13 | longyan
# Processing Record 21 of Set 13 | sharjah
# Processing Record 22 of Set 13 | pionerskiy
# Processing Record 23 of Set 13 | lufilufi
# Processing Record 24 of Set 13 | xinzhou
# Processing Record 25 of Set 13 | nowogard
# Processing Record 26 of Set 13 | kourou
# Processing Record 27 of Set 13 | yichang
# Processing Record 28 of Set 13 | nizhnyaya omka
# Processing Record 29 of Set 13 | akhtubinsk
# Processing Record 30 of Set 13 | ziro
# Processing Record 31 of Set 13 | salamiyah
# Processing Record 32 of Set 13 | koungou
# Processing Record 33 of Set 13 | nara
# Processing Record 34 of Set 13 | tayu
# Processing Record 35 of Set 13 | sitges
# Processing Record 36 of Set 13 | labuhan
# Processing Record 37 of Set 13 | belyy yar
# Processing Record 38 of Set 13 | balkhash
# Processing Record 39 of Set 13 | cherkasskoye
# Processing Record 40 of Set 13 | copiapo
# Processing Record 41 of Set 13 | anjangaon
# Processing Record 42 of Set 13 | sinnamary
# Processing Record 43 of Set 13 | belaya glina
# Processing Record 44 of Set 13 | alizai
# Processing Record 45 of Set 13 | manicore
# Processing Record 46 of Set 13 | candawaga
# City not found. Skipping...
# Processing Record 47 of Set 13 | bangui
# Processing Record 48 of Set 13 | reconquista
# Processing Record 49 of Set 13 | yerbogachen
# Processing Record 50 of Set 13 | pechenga
# Processing Record 1 of Set 14 | syasstroy
# Processing Record 2 of Set 14 | istok
# Processing Record 3 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 14 | umm lajj
# Processing Record 5 of Set 14 | leczna
# Processing Record 6 of Set 14 | altay
# Processing Record 7 of Set 14 | sheridan
# Processing Record 8 of Set 14 | saint-paul
# Processing Record 9 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 10 of Set 14 | moose factory
# Processing Record 11 of Set 14 | miles city
# Processing Record 12 of Set 14 | liuzhou
# Processing Record 13 of Set 14 | ranong
# Processing Record 14 of Set 14 | omboue
# Processing Record 15 of Set 14 | tokuyama
# Processing Record 16 of Set 14 | eureka
# Processing Record 17 of Set 14 | sulecin
# Processing Record 18 of Set 14 | muravlenko
# Processing Record 19 of Set 14 | tera
# Processing Record 20 of Set 14 | xichang
# Processing Record 21 of Set 14 | atherton
# Processing Record 22 of Set 14 | bayburt
# Processing Record 23 of Set 14 | novospasskoye
# Processing Record 24 of Set 14 | wuxue
# Processing Record 25 of Set 14 | gizo
# Processing Record 26 of Set 14 | wuwei
# Processing Record 27 of Set 14 | matongo
# Processing Record 28 of Set 14 | mezen
# Processing Record 29 of Set 14 | coslada
# Processing Record 30 of Set 14 | lluta
# Processing Record 31 of Set 14 | mohiuddinagar
# City not found. Skipping...
# Processing Record 32 of Set 14 | birin
# Processing Record 33 of Set 14 | mizdah
# Processing Record 34 of Set 14 | husavik
# Processing Record 35 of Set 14 | mirnyy
# Processing Record 36 of Set 14 | umea
# Processing Record 37 of Set 14 | likasi
# Processing Record 38 of Set 14 | necochea
# Processing Record 39 of Set 14 | thunder bay
# Processing Record 40 of Set 14 | north ogden
# Processing Record 41 of Set 14 | romanesti
# City not found. Skipping...
# Processing Record 42 of Set 14 | lewistown
# Processing Record 43 of Set 14 | nioro
# Processing Record 44 of Set 14 | motygino
# Processing Record 45 of Set 14 | abu samrah
# Processing Record 46 of Set 14 | houma
# Processing Record 47 of Set 14 | deh rawud
# City not found. Skipping...
# Processing Record 48 of Set 14 | yarkovo
# Processing Record 49 of Set 14 | la ronge
# Processing Record 50 of Set 14 | padampur
# Processing Record 1 of Set 15 | sakakah
# Processing Record 2 of Set 15 | calvinia
# Processing Record 3 of Set 15 | ahipara
# Processing Record 4 of Set 15 | sorong
# Processing Record 5 of Set 15 | quimperle
# Processing Record 6 of Set 15 | barcelos
# Processing Record 7 of Set 15 | zyryanka
# Processing Record 8 of Set 15 | ormara
# Processing Record 9 of Set 15 | itaparica
# Processing Record 10 of Set 15 | novyy urgal
# Processing Record 11 of Set 15 | evensk
# Processing Record 12 of Set 15 | progreso
# Processing Record 13 of Set 15 | nouakchott
# Processing Record 14 of Set 15 | morondava
# Processing Record 15 of Set 15 | sterling
# Processing Record 16 of Set 15 | port hawkesbury
# Processing Record 17 of Set 15 | muborak
# Processing Record 18 of Set 15 | seoul
# Processing Record 19 of Set 15 | port augusta
# Processing Record 20 of Set 15 | mende
# Processing Record 21 of Set 15 | kaeo
# Processing Record 22 of Set 15 | esperance
# Processing Record 23 of Set 15 | binga
# Processing Record 24 of Set 15 | krasnoyarsk
# Processing Record 25 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 26 of Set 15 | kinkala
# Processing Record 27 of Set 15 | bay saint louis
# Processing Record 28 of Set 15 | bumba
# Processing Record 29 of Set 15 | chicama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Mataura      NZ -46.1927  168.8643     59.49        60           7
# 1         Ushuaia      AR -54.8000  -68.3000     44.26        53          20
# 2          Albany      US  42.6001  -73.9662     51.17        79          66
# 3            Chuy      UY -33.6971  -53.4616     45.64        79         100
# 4     Port Alfred      ZA -33.5906   26.8910     61.52        72         100
# 5  Soto La Marina      MX  23.7667  -98.2167     72.77        92           0
# 6  Krasnyy Chikoy      RU  50.3643  108.7512     62.83        36          84
# 7        Tongliao      CN  43.6125  122.2653     56.37        69         100
# 8        Khatanga      RU  71.9667  102.5000     30.97        69          92
# 9        Bengkulu      ID  -3.8004  102.2655     82.33        72         100
#
#    Wind Speed Current Description
# 0        2.66           clear sky
# 1        8.05          few clouds
# 2        1.01       broken clouds
# 3        7.70     overcast clouds
# 4       16.78     overcast clouds
# 5        3.13           clear sky
# 6        7.76       broken clouds
# 7       17.16     overcast clouds
# 8       12.59     overcast clouds
# 9        6.85     overcast clouds

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
